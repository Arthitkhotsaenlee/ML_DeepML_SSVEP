# %%
# Import python library
import numpy as np
import mne
import matplotlib.pyplot as plt
import os
# %matplotlib notebook

# %%
folder = 'C:\\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data'

filepath1=os.path.join(folder,'SSVEP1.dat')
filepath2=os.path.join(folder,'SSVEP2.dat')
filepath3=os.path.join(folder,'SSVEP3.dat')
filepath4=os.path.join(folder,'SSVEP4.dat')
filepath5=os.path.join(folder,'SSVEP5.dat')
filepath6=os.path.join(folder,'SSVEP6.dat')

# %%
raw1=mne.io.read_raw_curry(filepath1)
raw2=mne.io.read_raw_curry(filepath2)
raw3=mne.io.read_raw_curry(filepath3)
raw4=mne.io.read_raw_curry(filepath4)
raw5=mne.io.read_raw_curry(filepath5)
raw6=mne.io.read_raw_curry(filepath6)
# Out:
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP1.ceo...
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP2.ceo...
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP3.ceo...
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP4.ceo...
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP5.ceo...
# Leaving device<->head transform as None (no landmarks found)
# Event file found. Extracting Annotations from C:\Users\OWNER\Desktop\Arthit Learn to Analysis EEG\SSVEP and EEGnet\Data\SSVEP6.ceo...

# %%
#pick only eeg
raw1.pick_types(eeg=True)
raw2.pick_types(eeg=True)
raw3.pick_types(eeg=True)
raw4.pick_types(eeg=True)
raw5.pick_types(eeg=True)
raw6.pick_types(eeg=True)
# Out:
# <RawCurry | SSVEP6.dat, 122 x 437500 (437.5 s), ~116 kB, data not loaded>

# %%
#apply BP filter and nouch filter
raw1.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw1.filter(l_freq=0.1,h_freq=None,method='iir')

raw2.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw2.filter(l_freq=0.1,h_freq=None,method='iir')

raw3.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw3.filter(l_freq=0.1,h_freq=None,method='iir')

raw4.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw4.filter(l_freq=0.1,h_freq=None,method='iir')

raw5.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw5.filter(l_freq=0.1,h_freq=None,method='iir')

raw6.load_data().notch_filter(np.arange(50,500,50),verbose=False)
raw6.filter(l_freq=0.1,h_freq=None,method='iir')
# Out:
# Reading 0 ... 458499  =      0.000 ...   458.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
#
# Reading 0 ... 425699  =      0.000 ...   425.699 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
#
# Reading 0 ... 458499  =      0.000 ...   458.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
#
# Reading 0 ... 466799  =      0.000 ...   466.799 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
#
# Reading 0 ... 447599  =      0.000 ...   447.599 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
#
# Reading 0 ... 437499  =      0.000 ...   437.499 secs...
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.1 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 0.10 Hz: -6.02 dB
# <RawCurry | SSVEP6.dat, 122 x 437500 (437.5 s), ~407.3 MB, data loaded>

# %%
# Annotation Function
#define duration each events
def find_net_annotation(raw_filted):
    raw=raw_filted
    for ann in range(17):
        raw_filted.annotations.duration[ann]=raw.annotations[ann+1]['onset']-raw.annotations[ann]['onset']
    # delete no need annotation 
    raw_filted.annotations.delete(np.arange(1,len(raw.annotations),2))
    raw_filted.annotations.onset
    #segmentation function
    def segment_eeg_data(start=None,end=None,duration=None,description=None):
        onset=list(np.arange(round(start),round(end),duration))
        return onset,[duration for j in range(len(onset))],[description for i in range(len(onset))]
    
    #declare variable
    onset=raw_filted.annotations.onset
    duration=raw_filted.annotations.duration
    labels=raw_filted.annotations.description
    end=np.round(onset+duration)
    onset_new=[]
    duration_new=[]
    descrip_new=[]
    for on,end,labs in zip(onset,end,labels):
        s,d,p=segment_eeg_data(start=on,end=end,duration=1,description=labs)
        onset_new.append(s)
        duration_new.append(d)
        descrip_new.append(p)
        
    #reshape data
    onset=[]
    duration=[]
    labels=[]
    for re in np.arange(len(onset_new)):
        onset=onset+onset_new[re]
        duration=duration+duration_new[re]
        labels=labels+descrip_new[re]
        
    #create annotation
    my_annot = mne.Annotations(onset=onset,  # in seconds
                               duration=duration,  # in seconds, too
                               description=labels)
    
    #Delete all old annotation
    raw_filted.annotations.delete(np.arange(0,len(raw_filted.annotations),1))
    
    #Set new annotation
    raw_filted.set_annotations(my_annot)
    return raw_filted

# %%
raw1=find_net_annotation(raw1.copy())
raw2=find_net_annotation(raw2.copy())
raw3=find_net_annotation(raw2.copy())
raw4=find_net_annotation(raw2.copy())
raw5=find_net_annotation(raw2.copy())
raw6=find_net_annotation(raw2.copy())

# %% [markdown]
# ## Epoch process

# %%
event1,_id1=mne.events_from_annotations(raw1)
event2,_id2=mne.events_from_annotations(raw2)
event3,_id3=mne.events_from_annotations(raw3)
event4,_id4=mne.events_from_annotations(raw4)
event5,_id5=mne.events_from_annotations(raw5)
event6,_id6=mne.events_from_annotations(raw6)
# Out:
# Used Annotations descriptions: ['10', '20', '30']
# Used Annotations descriptions: ['10', '20', '30']
# Used Annotations descriptions: ['10', '20', '30']
# Used Annotations descriptions: ['10', '20', '30']
# Used Annotations descriptions: ['10', '20', '30']
# Used Annotations descriptions: ['10', '20', '30']

# %%
pick_chs=[
 'PO11',
 'PO9',
 'PPO7',
 'PO3',
 'POO7',
 'OI1',
 'POO3',
 'Oz',
 'OI2',
 'POO4',
 'PO2',
 'PPO2',
 'POO8',
 'POO10h',
 'POO12h',
 'PO12',
 'PO10',
 'PPO8']

# %%
len(pick_chs)
# Out:
# 18

# %%
event_id={'10Hz':1,
          '20Hz':2,
          '30Hz':3
}

# %%
epochs1=mne.Epochs(raw1,event1,event_id,tmin=-0.1,tmax=1,picks=pick_chs)
epochs2=mne.Epochs(raw2,event2,event_id,tmin=-0.1,tmax=1,picks=pick_chs)
epochs3=mne.Epochs(raw3,event3,event_id,tmin=-0.1,tmax=1,picks=pick_chs)
epochs4=mne.Epochs(raw4,event4,event_id,tmin=-0.1,tmax=1,picks=pick_chs)
epochs5=mne.Epochs(raw5,event5,event_id,tmin=-0.1,tmax=1,picks=pick_chs)
epochs6=mne.Epochs(raw6,event6,event_id,tmin=-0.1,tmax=1,picks=pick_chs)

del raw1,raw2,raw3,raw4,raw5,raw6
# Out:
# Not setting metadata
# Not setting metadata
# 273 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# Not setting metadata
# 272 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# Not setting metadata
# 136 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# Not setting metadata
# 136 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# Not setting metadata
# 136 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Not setting metadata
# Not setting metadata
# 136 matching events found
# Setting baseline interval to [-0.1, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated

# %%
epochs1.load_data().filter(l_freq=4,h_freq=40,method='iir')
epochs2.load_data().filter(l_freq=4,h_freq=40,method='iir')
epochs3.load_data().filter(l_freq=4,h_freq=40,method='iir')
epochs4.load_data().filter(l_freq=4,h_freq=40,method='iir')
epochs5.load_data().filter(l_freq=4,h_freq=40,method='iir')
epochs6.load_data().filter(l_freq=4,h_freq=40,method='iir')
# Out:
# Loading data for 273 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Loading data for 272 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Loading data for 136 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Loading data for 136 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Loading data for 136 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
#
# Loading data for 136 events and 1101 original time points ...
# 0 bad epochs dropped
# Setting up band-pass filter from 4 - 40 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 16 (effective, after forward-backward)
# - Cutoffs at 4.00, 40.00 Hz: -6.02, -6.02 dB
# <Epochs |  136 events (all good), -0.1 - 1 sec, baseline -0.1 – 0 sec, ~20.6 MB, data loaded,
#  '10Hz': 46
#  '20Hz': 45
#  '30Hz': 45>

# %%
epochs1.set_eeg_reference(ref_channels='average',verbose=False)
epochs2.set_eeg_reference(ref_channels='average',verbose=False)
epochs3.set_eeg_reference(ref_channels='average',verbose=False)
epochs4.set_eeg_reference(ref_channels='average',verbose=False)
epochs5.set_eeg_reference(ref_channels='average',verbose=False)
epochs6.set_eeg_reference(ref_channels='average',verbose=False)
# Out:
# <Epochs |  136 events (all good), -0.1 - 1 sec, baseline -0.1 – 0 sec, ~20.6 MB, data loaded,
#  '10Hz': 46
#  '20Hz': 45
#  '30Hz': 45>

# %% [markdown]
# ## Preprocess data

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix,classification_report
## mne decoding library
from mne.decoding import Vectorizer,cross_val_multiscore,get_coef,Scaler

# %%
X1=epochs1.get_data()
X2=epochs2.get_data()
X3=epochs3.get_data()
X4=epochs4.get_data()
X5=epochs5.get_data()
X6=epochs6.get_data()

y1=epochs1.events[:,-1]
y2=epochs2.events[:,-1]
y3=epochs3.events[:,-1]
y4=epochs4.events[:,-1]
y5=epochs5.events[:,-1]
y6=epochs6.events[:,-1]

del epochs2,epochs3,epochs6,epochs4,epochs5,

# %%
X=np.concatenate((X1,X2,X3,X4,X5,X6),axis=0)
y=np.concatenate((y1,y2,y3,y4,y5,y6),axis=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
scaler=Scaler(epochs1.info)
scaler.fit(X_train,X_train.shape[0])
X_train=scaler.transform(X_train)
X_test=scaler.transform(X_test)

del epochs1

# %% [markdown]
# ##  EEGnet algorithm

# %%
from EEGModels import EEGNet,EEGnet_MindAmpltd
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import utils as np_utils

# %%
kernels,chans,samples=1,X.shape[1],X.shape[2]

# %%
class_weigths={0:1, 1:1, 2:1, 3:1}

# %%
yc_train = np_utils.to_categorical(y_train-1)
yc_test = np_utils.to_categorical(y_test-1)

# %%
#reshape X
Xc_train=X_train.reshape(X_train.shape[0],chans,samples,kernels)
Xc_test=X_test.reshape(X_test.shape[0],chans,samples,kernels)

# %%
# model=EEGNet(nb_classes=3,Chans=chans,Samples=samples,dropoutRate=0.5,
#             kernLength=500,F1=8,D=2,F2=16,dropoutType='Dropout')

model=EEGnet_MindAmpltd(nb_classes=3,Chans=chans,Samples=samples,
                        dropoutRate=0.75,norm_rate=0.3,kernLength=250,F1=25,D=2,F2=50,dropoutType='Dropout')

# %%
#model.compile(loss='CategoricalCrossentropy',optimizer='adam',metrics='accuracy')
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 18, 1101, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 18, 1101, 25)      6250
# _________________________________________________________________
# batch_normalization (BatchNo (None, 18, 1101, 25)      100
# _________________________________________________________________
# activation (Activation)      (None, 18, 1101, 25)      0
# _________________________________________________________________
# depthwise_conv2d (DepthwiseC (None, 1, 1101, 50)       900
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 1101, 50)       200
# _________________________________________________________________
# activation_1 (Activation)    (None, 1, 1101, 50)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 1, 275, 50)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 275, 50)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 1, 275, 50)        15000
# _________________________________________________________________
# activation_2 (Activation)    (None, 1, 275, 50)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 68, 50)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 68, 50)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3400)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 10203
# _________________________________________________________________
# softmax (Activation)         (None, 3)                 0
# =================================================================
# Total params: 32,653
# Trainable params: 32,503
# Non-trainable params: 150
# _________________________________________________________________

# %%
numParams=model.count_params()

# %%
checkpointer=ModelCheckpoint(filepath='Arthit Learn to Analysis EEG.h5',verbose=True,save_best_only=True)

# %%
fittedmodel=model.fit(Xc_train,yc_train,batch_size=32,epochs=100,verbose=True,
                      validation_split=0.25,callbacks=[checkpointer],class_weight=class_weigths)
# Out:
# Epoch 1/100
# 20/20 [==============================] - ETA: 0s - loss: 1.1840 - accuracy: 0.3644
# Epoch 00001: val_loss improved from inf to 1.09414, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 720ms/step - loss: 1.1840 - accuracy: 0.3644 - val_loss: 1.0941 - val_accuracy: 0.4020
# Epoch 2/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0852 - accuracy: 0.4134
# Epoch 00002: val_loss improved from 1.09414 to 1.08892, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 700ms/step - loss: 1.0852 - accuracy: 0.4134 - val_loss: 1.0889 - val_accuracy: 0.4265
# Epoch 3/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0574 - accuracy: 0.4542
# Epoch 00003: val_loss improved from 1.08892 to 1.07362, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 691ms/step - loss: 1.0574 - accuracy: 0.4542 - val_loss: 1.0736 - val_accuracy: 0.4804
# Epoch 4/100
# 20/20 [==============================] - ETA: 0s - loss: 1.0373 - accuracy: 0.4755
# Epoch 00004: val_loss improved from 1.07362 to 1.06964, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 691ms/step - loss: 1.0373 - accuracy: 0.4755 - val_loss: 1.0696 - val_accuracy: 0.4804
# Epoch 5/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9599 - accuracy: 0.5474
# Epoch 00005: val_loss improved from 1.06964 to 1.04860, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 698ms/step - loss: 0.9599 - accuracy: 0.5474 - val_loss: 1.0486 - val_accuracy: 0.5049
# Epoch 6/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9356 - accuracy: 0.5670
# Epoch 00006: val_loss improved from 1.04860 to 1.02691, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 712ms/step - loss: 0.9356 - accuracy: 0.5670 - val_loss: 1.0269 - val_accuracy: 0.4853
# Epoch 7/100
# 20/20 [==============================] - ETA: 0s - loss: 0.9502 - accuracy: 0.5376
# Epoch 00007: val_loss improved from 1.02691 to 1.00402, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 695ms/step - loss: 0.9502 - accuracy: 0.5376 - val_loss: 1.0040 - val_accuracy: 0.5588
# Epoch 8/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8666 - accuracy: 0.5882
# Epoch 00008: val_loss improved from 1.00402 to 0.94566, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 691ms/step - loss: 0.8666 - accuracy: 0.5882 - val_loss: 0.9457 - val_accuracy: 0.5833
# Epoch 9/100
# 20/20 [==============================] - ETA: 0s - loss: 0.8232 - accuracy: 0.6454
# Epoch 00009: val_loss improved from 0.94566 to 0.89862, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 691ms/step - loss: 0.8232 - accuracy: 0.6454 - val_loss: 0.8986 - val_accuracy: 0.6471
# Epoch 10/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7639 - accuracy: 0.6618
# Epoch 00010: val_loss improved from 0.89862 to 0.84766, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 695ms/step - loss: 0.7639 - accuracy: 0.6618 - val_loss: 0.8477 - val_accuracy: 0.6471
# Epoch 11/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7324 - accuracy: 0.6634
# Epoch 00011: val_loss improved from 0.84766 to 0.80844, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 695ms/step - loss: 0.7324 - accuracy: 0.6634 - val_loss: 0.8084 - val_accuracy: 0.7059
# Epoch 12/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6975 - accuracy: 0.6846
# Epoch 00012: val_loss improved from 0.80844 to 0.77080, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 700ms/step - loss: 0.6975 - accuracy: 0.6846 - val_loss: 0.7708 - val_accuracy: 0.6814
# Epoch 13/100
# 20/20 [==============================] - ETA: 0s - loss: 0.7625 - accuracy: 0.6389
# Epoch 00013: val_loss improved from 0.77080 to 0.74097, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 707ms/step - loss: 0.7625 - accuracy: 0.6389 - val_loss: 0.7410 - val_accuracy: 0.6716
# Epoch 14/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6677 - accuracy: 0.7092
# Epoch 00014: val_loss improved from 0.74097 to 0.72493, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 710ms/step - loss: 0.6677 - accuracy: 0.7092 - val_loss: 0.7249 - val_accuracy: 0.6863
# Epoch 15/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6706 - accuracy: 0.6944
# Epoch 00015: val_loss improved from 0.72493 to 0.69422, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 699ms/step - loss: 0.6706 - accuracy: 0.6944 - val_loss: 0.6942 - val_accuracy: 0.7304
# Epoch 16/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6009 - accuracy: 0.7418
# Epoch 00016: val_loss improved from 0.69422 to 0.68011, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 693ms/step - loss: 0.6009 - accuracy: 0.7418 - val_loss: 0.6801 - val_accuracy: 0.7010
# Epoch 17/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6173 - accuracy: 0.7239
# Epoch 00017: val_loss improved from 0.68011 to 0.61186, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 690ms/step - loss: 0.6173 - accuracy: 0.7239 - val_loss: 0.6119 - val_accuracy: 0.8039
# Epoch 18/100
# 20/20 [==============================] - ETA: 0s - loss: 0.6186 - accuracy: 0.7288
# Epoch 00018: val_loss did not improve from 0.61186
# 20/20 [==============================] - 14s 695ms/step - loss: 0.6186 - accuracy: 0.7288 - val_loss: 0.6230 - val_accuracy: 0.7647
# Epoch 19/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5888 - accuracy: 0.7239
# Epoch 00019: val_loss improved from 0.61186 to 0.59066, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 697ms/step - loss: 0.5888 - accuracy: 0.7239 - val_loss: 0.5907 - val_accuracy: 0.8039
# Epoch 20/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.7908
# Epoch 00020: val_loss improved from 0.59066 to 0.55086, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.4953 - accuracy: 0.7908 - val_loss: 0.5509 - val_accuracy: 0.8039
# Epoch 21/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5052 - accuracy: 0.7892
# Epoch 00021: val_loss improved from 0.55086 to 0.50260, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 699ms/step - loss: 0.5052 - accuracy: 0.7892 - val_loss: 0.5026 - val_accuracy: 0.8431
# Epoch 22/100
# 20/20 [==============================] - ETA: 0s - loss: 0.5295 - accuracy: 0.7794
# Epoch 00022: val_loss improved from 0.50260 to 0.49208, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 698ms/step - loss: 0.5295 - accuracy: 0.7794 - val_loss: 0.4921 - val_accuracy: 0.8186
# Epoch 23/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.7941
# Epoch 00023: val_loss improved from 0.49208 to 0.47482, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 703ms/step - loss: 0.4776 - accuracy: 0.7941 - val_loss: 0.4748 - val_accuracy: 0.7990
# Epoch 24/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4689 - accuracy: 0.7843
# Epoch 00024: val_loss improved from 0.47482 to 0.46768, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 704ms/step - loss: 0.4689 - accuracy: 0.7843 - val_loss: 0.4677 - val_accuracy: 0.8186
# Epoch 25/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.7892
# Epoch 00025: val_loss improved from 0.46768 to 0.42115, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 695ms/step - loss: 0.4753 - accuracy: 0.7892 - val_loss: 0.4211 - val_accuracy: 0.8529
# Epoch 26/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4398 - accuracy: 0.8235
# Epoch 00026: val_loss improved from 0.42115 to 0.40329, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 704ms/step - loss: 0.4398 - accuracy: 0.8235 - val_loss: 0.4033 - val_accuracy: 0.8578
# Epoch 27/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8497
# Epoch 00027: val_loss improved from 0.40329 to 0.38953, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 699ms/step - loss: 0.3968 - accuracy: 0.8497 - val_loss: 0.3895 - val_accuracy: 0.8725
# Epoch 28/100
# 20/20 [==============================] - ETA: 0s - loss: 0.4270 - accuracy: 0.8301
# Epoch 00028: val_loss improved from 0.38953 to 0.36140, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 690ms/step - loss: 0.4270 - accuracy: 0.8301 - val_loss: 0.3614 - val_accuracy: 0.8627
# Epoch 29/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.8725
# Epoch 00029: val_loss did not improve from 0.36140
# 20/20 [==============================] - 14s 691ms/step - loss: 0.3427 - accuracy: 0.8725 - val_loss: 0.3771 - val_accuracy: 0.8676
# Epoch 30/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3572 - accuracy: 0.8775
# Epoch 00030: val_loss did not improve from 0.36140
# 20/20 [==============================] - 14s 688ms/step - loss: 0.3572 - accuracy: 0.8775 - val_loss: 0.3703 - val_accuracy: 0.8627
# Epoch 31/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3699 - accuracy: 0.8676
# Epoch 00031: val_loss did not improve from 0.36140
# 20/20 [==============================] - 14s 704ms/step - loss: 0.3699 - accuracy: 0.8676 - val_loss: 0.3981 - val_accuracy: 0.8578
# Epoch 32/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3992 - accuracy: 0.8350
# Epoch 00032: val_loss improved from 0.36140 to 0.34948, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 702ms/step - loss: 0.3992 - accuracy: 0.8350 - val_loss: 0.3495 - val_accuracy: 0.8578
# Epoch 33/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.8660
# Epoch 00033: val_loss improved from 0.34948 to 0.34287, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 700ms/step - loss: 0.3591 - accuracy: 0.8660 - val_loss: 0.3429 - val_accuracy: 0.8627
# Epoch 34/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3521 - accuracy: 0.8676
# Epoch 00034: val_loss improved from 0.34287 to 0.29801, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 697ms/step - loss: 0.3521 - accuracy: 0.8676 - val_loss: 0.2980 - val_accuracy: 0.9020
# Epoch 35/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3143 - accuracy: 0.8676
# Epoch 00035: val_loss did not improve from 0.29801
# 20/20 [==============================] - 14s 689ms/step - loss: 0.3143 - accuracy: 0.8676 - val_loss: 0.3081 - val_accuracy: 0.8725
# Epoch 36/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3252 - accuracy: 0.8660
# Epoch 00036: val_loss did not improve from 0.29801
# 20/20 [==============================] - 14s 693ms/step - loss: 0.3252 - accuracy: 0.8660 - val_loss: 0.3341 - val_accuracy: 0.8382
# Epoch 37/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3286 - accuracy: 0.8676
# Epoch 00037: val_loss improved from 0.29801 to 0.29777, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 689ms/step - loss: 0.3286 - accuracy: 0.8676 - val_loss: 0.2978 - val_accuracy: 0.8676
# Epoch 38/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3023 - accuracy: 0.8791
# Epoch 00038: val_loss improved from 0.29777 to 0.28845, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 699ms/step - loss: 0.3023 - accuracy: 0.8791 - val_loss: 0.2885 - val_accuracy: 0.8824
# Epoch 39/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3141 - accuracy: 0.8725
# Epoch 00039: val_loss did not improve from 0.28845
# 20/20 [==============================] - 14s 704ms/step - loss: 0.3141 - accuracy: 0.8725 - val_loss: 0.3100 - val_accuracy: 0.9069
# Epoch 40/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.9003
# Epoch 00040: val_loss improved from 0.28845 to 0.27993, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.2869 - accuracy: 0.9003 - val_loss: 0.2799 - val_accuracy: 0.8873
# Epoch 41/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3126 - accuracy: 0.8725
# Epoch 00041: val_loss did not improve from 0.27993
# 20/20 [==============================] - 14s 694ms/step - loss: 0.3126 - accuracy: 0.8725 - val_loss: 0.3067 - val_accuracy: 0.8725
# Epoch 42/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8480
# Epoch 00042: val_loss did not improve from 0.27993
# 20/20 [==============================] - 14s 687ms/step - loss: 0.3864 - accuracy: 0.8480 - val_loss: 0.3782 - val_accuracy: 0.8235
# Epoch 43/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8725
# Epoch 00043: val_loss did not improve from 0.27993
# 20/20 [==============================] - 14s 689ms/step - loss: 0.3265 - accuracy: 0.8725 - val_loss: 0.3214 - val_accuracy: 0.8480
# Epoch 44/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.9052
# Epoch 00044: val_loss did not improve from 0.27993
# 20/20 [==============================] - 14s 688ms/step - loss: 0.2480 - accuracy: 0.9052 - val_loss: 0.2847 - val_accuracy: 0.8725
# Epoch 45/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2578 - accuracy: 0.9101
# Epoch 00045: val_loss improved from 0.27993 to 0.24305, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.2578 - accuracy: 0.9101 - val_loss: 0.2431 - val_accuracy: 0.9020
# Epoch 46/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9052
# Epoch 00046: val_loss did not improve from 0.24305
# 20/20 [==============================] - 14s 688ms/step - loss: 0.2471 - accuracy: 0.9052 - val_loss: 0.2518 - val_accuracy: 0.9069
# Epoch 47/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2861 - accuracy: 0.8922
# Epoch 00047: val_loss did not improve from 0.24305
# 20/20 [==============================] - 14s 694ms/step - loss: 0.2861 - accuracy: 0.8922 - val_loss: 0.2662 - val_accuracy: 0.9020
# Epoch 48/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2692 - accuracy: 0.8938
# Epoch 00048: val_loss improved from 0.24305 to 0.23088, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.2692 - accuracy: 0.8938 - val_loss: 0.2309 - val_accuracy: 0.9118
# Epoch 49/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2489 - accuracy: 0.8954
# Epoch 00049: val_loss did not improve from 0.23088
# 20/20 [==============================] - 14s 687ms/step - loss: 0.2489 - accuracy: 0.8954 - val_loss: 0.2699 - val_accuracy: 0.9020
# Epoch 50/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.8987
# Epoch 00050: val_loss improved from 0.23088 to 0.22128, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 695ms/step - loss: 0.2681 - accuracy: 0.8987 - val_loss: 0.2213 - val_accuracy: 0.9314
# Epoch 51/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9052
# Epoch 00051: val_loss did not improve from 0.22128
# 20/20 [==============================] - 14s 689ms/step - loss: 0.2527 - accuracy: 0.9052 - val_loss: 0.2242 - val_accuracy: 0.9216
# Epoch 52/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2372 - accuracy: 0.9101
# Epoch 00052: val_loss did not improve from 0.22128
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2372 - accuracy: 0.9101 - val_loss: 0.2628 - val_accuracy: 0.8725
# Epoch 53/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3113 - accuracy: 0.8709
# Epoch 00053: val_loss did not improve from 0.22128
# 20/20 [==============================] - 14s 683ms/step - loss: 0.3113 - accuracy: 0.8709 - val_loss: 0.2288 - val_accuracy: 0.9314
# Epoch 54/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9150
# Epoch 00054: val_loss improved from 0.22128 to 0.20445, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 693ms/step - loss: 0.2175 - accuracy: 0.9150 - val_loss: 0.2044 - val_accuracy: 0.9412
# Epoch 55/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2754 - accuracy: 0.8807
# Epoch 00055: val_loss improved from 0.20445 to 0.20185, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 693ms/step - loss: 0.2754 - accuracy: 0.8807 - val_loss: 0.2018 - val_accuracy: 0.9167
# Epoch 56/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2231 - accuracy: 0.9150
# Epoch 00056: val_loss improved from 0.20185 to 0.18901, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.2231 - accuracy: 0.9150 - val_loss: 0.1890 - val_accuracy: 0.9461
# Epoch 57/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2109 - accuracy: 0.9265
# Epoch 00057: val_loss did not improve from 0.18901
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2109 - accuracy: 0.9265 - val_loss: 0.2015 - val_accuracy: 0.9216
# Epoch 58/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.8987
# Epoch 00058: val_loss did not improve from 0.18901
# 20/20 [==============================] - 14s 700ms/step - loss: 0.2466 - accuracy: 0.8987 - val_loss: 0.2096 - val_accuracy: 0.9069
# Epoch 59/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2970 - accuracy: 0.8676
# Epoch 00059: val_loss did not improve from 0.18901
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2970 - accuracy: 0.8676 - val_loss: 0.2101 - val_accuracy: 0.9314
# Epoch 60/100
# 20/20 [==============================] - ETA: 0s - loss: 0.3152 - accuracy: 0.8758
# Epoch 00060: val_loss did not improve from 0.18901
# 20/20 [==============================] - 14s 689ms/step - loss: 0.3152 - accuracy: 0.8758 - val_loss: 0.2156 - val_accuracy: 0.9265
# Epoch 61/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9069
# Epoch 00061: val_loss improved from 0.18901 to 0.18304, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 684ms/step - loss: 0.2156 - accuracy: 0.9069 - val_loss: 0.1830 - val_accuracy: 0.9314
# Epoch 62/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9150
# Epoch 00062: val_loss did not improve from 0.18304
# 20/20 [==============================] - 14s 681ms/step - loss: 0.2115 - accuracy: 0.9150 - val_loss: 0.2252 - val_accuracy: 0.9216
# Epoch 63/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9216
# Epoch 00063: val_loss did not improve from 0.18304
# 20/20 [==============================] - 14s 683ms/step - loss: 0.2009 - accuracy: 0.9216 - val_loss: 0.2635 - val_accuracy: 0.8824
# Epoch 64/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2610 - accuracy: 0.8987
# Epoch 00064: val_loss did not improve from 0.18304
# 20/20 [==============================] - 14s 686ms/step - loss: 0.2610 - accuracy: 0.8987 - val_loss: 0.1846 - val_accuracy: 0.9412
# Epoch 65/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2281 - accuracy: 0.9052
# Epoch 00065: val_loss did not improve from 0.18304
# 20/20 [==============================] - 14s 680ms/step - loss: 0.2281 - accuracy: 0.9052 - val_loss: 0.2401 - val_accuracy: 0.8578
# Epoch 66/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9118
# Epoch 00066: val_loss improved from 0.18304 to 0.17649, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 681ms/step - loss: 0.2352 - accuracy: 0.9118 - val_loss: 0.1765 - val_accuracy: 0.9314
# Epoch 67/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2103 - accuracy: 0.9216
# Epoch 00067: val_loss did not improve from 0.17649
# 20/20 [==============================] - 14s 681ms/step - loss: 0.2103 - accuracy: 0.9216 - val_loss: 0.2142 - val_accuracy: 0.9069
# Epoch 68/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9395
# Epoch 00068: val_loss did not improve from 0.17649
# 20/20 [==============================] - 14s 679ms/step - loss: 0.1675 - accuracy: 0.9395 - val_loss: 0.1869 - val_accuracy: 0.9363
# Epoch 69/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9559
# Epoch 00069: val_loss did not improve from 0.17649
# 20/20 [==============================] - 14s 678ms/step - loss: 0.1464 - accuracy: 0.9559 - val_loss: 0.1795 - val_accuracy: 0.9216
# Epoch 70/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9265
# Epoch 00070: val_loss did not improve from 0.17649
# 20/20 [==============================] - 14s 683ms/step - loss: 0.1931 - accuracy: 0.9265 - val_loss: 0.2076 - val_accuracy: 0.9363
# Epoch 71/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9232
# Epoch 00071: val_loss improved from 0.17649 to 0.16614, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 685ms/step - loss: 0.2158 - accuracy: 0.9232 - val_loss: 0.1661 - val_accuracy: 0.9559
# Epoch 72/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9395
# Epoch 00072: val_loss did not improve from 0.16614
# 20/20 [==============================] - 14s 681ms/step - loss: 0.1701 - accuracy: 0.9395 - val_loss: 0.1699 - val_accuracy: 0.9412
# Epoch 73/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1523 - accuracy: 0.9510
# Epoch 00073: val_loss did not improve from 0.16614
# 20/20 [==============================] - 14s 680ms/step - loss: 0.1523 - accuracy: 0.9510 - val_loss: 0.2064 - val_accuracy: 0.9069
# Epoch 74/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9297
# Epoch 00074: val_loss did not improve from 0.16614
# 20/20 [==============================] - 14s 683ms/step - loss: 0.1904 - accuracy: 0.9297 - val_loss: 0.2358 - val_accuracy: 0.8775
# Epoch 75/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9363
# Epoch 00075: val_loss did not improve from 0.16614
# 20/20 [==============================] - 14s 681ms/step - loss: 0.1722 - accuracy: 0.9363 - val_loss: 0.1672 - val_accuracy: 0.9461
# Epoch 76/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1712 - accuracy: 0.9428
# Epoch 00076: val_loss improved from 0.16614 to 0.15795, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 711ms/step - loss: 0.1712 - accuracy: 0.9428 - val_loss: 0.1580 - val_accuracy: 0.9510
# Epoch 77/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9118
# Epoch 00077: val_loss did not improve from 0.15795
# 20/20 [==============================] - 14s 692ms/step - loss: 0.2570 - accuracy: 0.9118 - val_loss: 0.3067 - val_accuracy: 0.8284
# Epoch 78/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2480 - accuracy: 0.9036
# Epoch 00078: val_loss did not improve from 0.15795
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2480 - accuracy: 0.9036 - val_loss: 0.2253 - val_accuracy: 0.9020
# Epoch 79/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9281
# Epoch 00079: val_loss did not improve from 0.15795
# 20/20 [==============================] - 14s 684ms/step - loss: 0.2028 - accuracy: 0.9281 - val_loss: 0.2142 - val_accuracy: 0.9167
# Epoch 80/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9346
# Epoch 00080: val_loss improved from 0.15795 to 0.15071, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 693ms/step - loss: 0.1867 - accuracy: 0.9346 - val_loss: 0.1507 - val_accuracy: 0.9559
# Epoch 81/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9657
# Epoch 00081: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 687ms/step - loss: 0.1309 - accuracy: 0.9657 - val_loss: 0.1628 - val_accuracy: 0.9510
# Epoch 82/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9216
# Epoch 00082: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 688ms/step - loss: 0.2061 - accuracy: 0.9216 - val_loss: 0.1551 - val_accuracy: 0.9706
# Epoch 83/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9477
# Epoch 00083: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 681ms/step - loss: 0.1568 - accuracy: 0.9477 - val_loss: 0.1641 - val_accuracy: 0.9314
# Epoch 84/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9363
# Epoch 00084: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 687ms/step - loss: 0.1643 - accuracy: 0.9363 - val_loss: 0.2031 - val_accuracy: 0.9216
# Epoch 85/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9199
# Epoch 00085: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 687ms/step - loss: 0.2347 - accuracy: 0.9199 - val_loss: 0.1615 - val_accuracy: 0.9559
# Epoch 86/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.9216
# Epoch 00086: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 683ms/step - loss: 0.1810 - accuracy: 0.9216 - val_loss: 0.2006 - val_accuracy: 0.9167
# Epoch 87/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9379
# Epoch 00087: val_loss did not improve from 0.15071
# 20/20 [==============================] - 14s 687ms/step - loss: 0.1690 - accuracy: 0.9379 - val_loss: 0.1612 - val_accuracy: 0.9608
# Epoch 88/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9379
# Epoch 00088: val_loss improved from 0.15071 to 0.14357, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 694ms/step - loss: 0.1720 - accuracy: 0.9379 - val_loss: 0.1436 - val_accuracy: 0.9608
# Epoch 89/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9493
# Epoch 00089: val_loss improved from 0.14357 to 0.13894, saving model to Arthit Learn to Analysis EEG.h5
# 20/20 [==============================] - 14s 706ms/step - loss: 0.1545 - accuracy: 0.9493 - val_loss: 0.1389 - val_accuracy: 0.9706
# Epoch 90/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2088 - accuracy: 0.9199
# Epoch 00090: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 684ms/step - loss: 0.2088 - accuracy: 0.9199 - val_loss: 0.1728 - val_accuracy: 0.9510
# Epoch 91/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9444
# Epoch 00091: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 697ms/step - loss: 0.1646 - accuracy: 0.9444 - val_loss: 0.1401 - val_accuracy: 0.9559
# Epoch 92/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9412
# Epoch 00092: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 683ms/step - loss: 0.1574 - accuracy: 0.9412 - val_loss: 0.1655 - val_accuracy: 0.9363
# Epoch 93/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9444
# Epoch 00093: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 684ms/step - loss: 0.1400 - accuracy: 0.9444 - val_loss: 0.1906 - val_accuracy: 0.9167
# Epoch 94/100
# 20/20 [==============================] - ETA: 0s - loss: 0.2014 - accuracy: 0.9199
# Epoch 00094: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 690ms/step - loss: 0.2014 - accuracy: 0.9199 - val_loss: 0.1862 - val_accuracy: 0.9216
# Epoch 95/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9444
# Epoch 00095: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 682ms/step - loss: 0.1941 - accuracy: 0.9444 - val_loss: 0.1484 - val_accuracy: 0.9265
# Epoch 96/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9265
# Epoch 00096: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 693ms/step - loss: 0.1820 - accuracy: 0.9265 - val_loss: 0.1750 - val_accuracy: 0.9412
# Epoch 97/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9330
# Epoch 00097: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 689ms/step - loss: 0.1569 - accuracy: 0.9330 - val_loss: 0.1603 - val_accuracy: 0.9363
# Epoch 98/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9363
# Epoch 00098: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 684ms/step - loss: 0.1722 - accuracy: 0.9363 - val_loss: 0.1461 - val_accuracy: 0.9608
# Epoch 99/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9395
# Epoch 00099: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 688ms/step - loss: 0.1773 - accuracy: 0.9395 - val_loss: 0.1420 - val_accuracy: 0.9706
# Epoch 100/100
# 20/20 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9379
# Epoch 00100: val_loss did not improve from 0.13894
# 20/20 [==============================] - 14s 681ms/step - loss: 0.1710 - accuracy: 0.9379 - val_loss: 0.1513 - val_accuracy: 0.9657

# %%
model.load_weights('Arthit Learn to Analysis EEG.h5')

# %%
probs=model.predict(Xc_test)
preds=probs.argmax(axis=-1)
acc=np.mean(preds==yc_test.argmax(axis=-1))

# %%
acc
# Out:
# 0.8901098901098901

# %%
preds=preds+1

# %%
preds
# Out:
# array([2, 1, 2, 3, 1, 3, 3, 2, 2, 3, 1, 2, 3, 1, 3, 3, 3, 3, 3, 2, 1, 2,
#        2, 1, 3, 3, 3, 3, 2, 1, 3, 3, 1, 3, 1, 1, 2, 2, 2, 1, 3, 3, 3, 1,
#        2, 3, 3, 2, 2, 3, 1, 2, 3, 1, 1, 2, 3, 1, 3, 2, 2, 2, 3, 3, 1, 2,
#        2, 1, 3, 2, 3, 2, 2, 1, 3, 2, 3, 3, 3, 3, 1, 2, 2, 2, 3, 2, 1, 1,
#        3, 1, 2, 2, 3, 3, 2, 3, 3, 1, 1, 3, 2, 1, 3, 3, 1, 2, 3, 2, 3, 3,
#        3, 3, 1, 3, 3, 2, 1, 1, 3, 1, 3, 2, 1, 3, 1, 3, 1, 3, 2, 3, 1, 1,
#        2, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 1, 2, 2, 3,
#        1, 2, 3, 1, 1, 1, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 2, 2, 2, 2, 3,
#        3, 1, 3, 3, 3, 1, 2, 2, 3, 2, 2, 3, 2, 1, 3, 1, 3, 2, 1, 3, 1, 3,
#        3, 3, 1, 1, 2, 1, 1, 1, 3, 3, 2, 3, 2, 1, 2, 2, 1, 3, 2, 2, 3, 1,
#        3, 1, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 3, 1, 2, 1, 3, 2, 3, 2,
#        3, 1, 3, 3, 3, 3, 3, 1, 3, 2, 1, 1, 3, 1, 3, 1, 3, 3, 3, 1, 2, 3,
#        2, 3, 1, 2, 2, 2, 3, 1, 3], dtype=int64)

# %%
print(confusion_matrix(y_test,preds))
print(classification_report(y_test,preds))
# Out:
# [[ 74   4   6]
#  [  0  68  15]
#  [  0   5 101]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.88      0.94        84
#            2       0.88      0.82      0.85        83
#            3       0.83      0.95      0.89       106
#
#     accuracy                           0.89       273
#    macro avg       0.90      0.88      0.89       273
# weighted avg       0.90      0.89      0.89       273

# %%
preds
# Out:
# array([2, 1, 2, 3, 1, 3, 3, 2, 2, 3, 1, 2, 3, 1, 3, 3, 3, 3, 3, 2, 1, 2,
#        2, 1, 3, 3, 3, 3, 2, 1, 3, 3, 1, 3, 1, 1, 2, 2, 2, 1, 3, 3, 3, 1,
#        2, 3, 3, 2, 2, 3, 1, 2, 3, 1, 1, 2, 3, 1, 3, 2, 2, 2, 3, 3, 1, 2,
#        2, 1, 3, 2, 3, 2, 2, 1, 3, 2, 3, 3, 3, 3, 1, 2, 2, 2, 3, 2, 1, 1,
#        3, 1, 2, 2, 3, 3, 2, 3, 3, 1, 1, 3, 2, 1, 3, 3, 1, 2, 3, 2, 3, 3,
#        3, 3, 1, 3, 3, 2, 1, 1, 3, 1, 3, 2, 1, 3, 1, 3, 1, 3, 2, 3, 1, 1,
#        2, 3, 1, 1, 2, 3, 3, 3, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 1, 2, 2, 3,
#        1, 2, 3, 1, 1, 1, 1, 3, 1, 3, 3, 2, 2, 3, 2, 1, 1, 2, 2, 2, 2, 3,
#        3, 1, 3, 3, 3, 1, 2, 2, 3, 2, 2, 3, 2, 1, 3, 1, 3, 2, 1, 3, 1, 3,
#        3, 3, 1, 1, 2, 1, 1, 1, 3, 3, 2, 3, 2, 1, 2, 2, 1, 3, 2, 2, 3, 1,
#        3, 1, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 3, 1, 2, 1, 3, 2, 3, 2,
#        3, 1, 3, 3, 3, 3, 3, 1, 3, 2, 1, 1, 3, 1, 3, 1, 3, 3, 3, 1, 2, 3,
#        2, 3, 1, 2, 2, 2, 3, 1, 3], dtype=int64)

# %% [markdown]
# ## plot History

# %%
plt.plot(fittedmodel.history['accuracy'])
plt.plot(fittedmodel.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend(['Train','varidation'],loc='lower right')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#loss
plt.plot(fittedmodel.history['loss'])
plt.plot(fittedmodel.history['val_loss'])
plt.title('Model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Train','varidation'],loc='lower right')
plt.show()

# %%
model.save(filepath='6Subject_model.h5',save_format='h5')
